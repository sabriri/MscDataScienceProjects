# %% [markdown]
# ### Cleaning and Enriching the data
#
# The scraped data includes the following things that need to be cleaned up:
#
# - {""} in the Character_name columns
# - Sometimes ; in the end of a value
# - Names within character_name have []
# - Duplicates need to be cleaned up
# - The order and the index needs to be fixed

# %%
import pandas as pd
import numpy as np

# %%
df_B_stage2 = pd.read_csv("../Data/B_stage2.csv", delimiter = ",")

# %%
df_B_stage2
# Out:
#        award_year                    category  \
# 0     1989 (62nd)                   DIRECTING
# 1     1957 (30th)             MUSIC (Scoring)
# 2     1992 (65th)              VISUAL EFFECTS
# 3     2001 (74th)    SHORT FILM (Live Action)
# 4     2014 (87th)  ACTOR IN A SUPPORTING ROLE
# ...           ...                         ...
# 2648  1942 (15th)                MUSIC (Song)
# 2649  2019 (92nd)     ACTOR IN A LEADING ROLE
# 2650  2019 (92nd)       ANIMATED FEATURE FILM
# 2651   1935 (8th)    WRITING (Original Story)
# 2652  2011 (84th)     ACTOR IN A LEADING ROLE
#
#                                                   name1 name2 name3  \
# 0                                          Oliver Stone   NaN   NaN
# 1                                        Malcolm Arnold   NaN   NaN
# 2     Ken Ralston, Doug Chiang, Doug Smythe, Tom Woo...   NaN   NaN
# 3                             Ray McKinnon, Lisa Blount   NaN   NaN
# 4                                          J.K. Simmons   NaN   NaN
# ...                                                 ...   ...   ...
# 2648                  Music and Lyrics by Irving Berlin   NaN   NaN
# 2649                                    Joaquin Phoenix   NaN   NaN
# 2650         Josh Cooley, Mark Nielsen and Jonas Rivera   NaN   NaN
# 2651                       Ben Hecht, Charles MacArthur   NaN   NaN
# 2652                                      Jean Dujardin   NaN   NaN
#
#                         film_title       character_name film_title2  \
# 0       Born on the Fourth of July                  NaN         NaN
# 1     The Bridge on the River Kwai                  NaN         NaN
# 2                Death Becomes Her                  NaN         NaN
# 3                   the accountant                  NaN         NaN
# 4                         Whiplash         {"Fletcher"}         NaN
# ...                            ...                  ...         ...
# 2648                   Holiday Inn                  NaN         NaN
# 2649                         Joker     {"Arthur Fleck"}         NaN
# 2650                   Toy Story 4                  NaN         NaN
# 2651                 The Scoundrel                  NaN         NaN
# 2652                    The Artist  {"George Valentin"}         NaN
#
#      character_name2 film_title3 character_name3 film_title4  character_name4  \
# 0                NaN         NaN             NaN         NaN              NaN
# 1                NaN         NaN             NaN         NaN              NaN
# 2                NaN         NaN             NaN         NaN              NaN
# 3                NaN         NaN             NaN         NaN              NaN
# 4                NaN         NaN             NaN         NaN              NaN
# ...              ...         ...             ...         ...              ...
# 2648             NaN         NaN             NaN         NaN              NaN
# 2649             NaN         NaN             NaN         NaN              NaN
# 2650             NaN         NaN             NaN         NaN              NaN
# 2651             NaN         NaN             NaN         NaN              NaN
# 2652             NaN         NaN             NaN         NaN              NaN
#
#      honorary_statement description note
# 0                   NaN         NaN  NaN
# 1                   NaN         NaN  NaN
# 2                   NaN         NaN  NaN
# 3                   NaN         NaN  NaN
# 4                   NaN         NaN  NaN
# ...                 ...         ...  ...
# 2648                NaN         NaN  NaN
# 2649                NaN         NaN  NaN
# 2650                NaN         NaN  NaN
# 2651                NaN         NaN  NaN
# 2652                NaN         NaN  NaN
#
# [2653 rows x 16 columns]

# %% [markdown]
# ### 1. Cleaning of the data
#
# #### 1.1 Changing the order
#
# It becomes quite obvious that the order of the entries is not the same as it is on the website. The aim here is to begin again with the 1st oscars and then go up to the 95th.
#
# The order needs to be fixed and afterwards it needs to be sorted by category. The index will also be resetted.

# %%
df = df_B_stage2.sort_values(by=['award_year', 'category'], ascending = [True, True]).reset_index(drop=True)

# %% [markdown]
# #### 1.2 Create separate rows and delete everything after 2017
#
# Split the Years from the number representing the how maniest time the oscars took place. Therefore, two new columns were created the year and the oscars_count. The columns are rearranged.
#
# All the years after 2017 were deleted.

# %%
#create two separate rows with the years and the number
df[['year', 'oscars_count']] = df['award_year'].str.extract(r'(\d{4}(?:/\d{2})?) \((\d+)\w*\)')
df = df[['year', 'oscars_count', 'award_year','category', 'name1', 'name2', 'name3', 'film_title', 'character_name', 
         'film_title2','character_name2','film_title3','character_name3','film_title4','character_name4',
         'honorary_statement','description','note']]
#delete all the years after 2017
df = df.loc[df.year < '2018']

df
# Out:
#          year oscars_count     award_year                       category  \
# 0     1927/28            1  1927/28 (1st)                          ACTOR
# 1     1927/28            1  1927/28 (1st)                        ACTRESS
# 2     1927/28            1  1927/28 (1st)                  ART DIRECTION
# 3     1927/28            1  1927/28 (1st)                 CINEMATOGRAPHY
# 4     1927/28            1  1927/28 (1st)     DIRECTING (Comedy Picture)
# ...       ...          ...            ...                            ...
# 2510     2017           90    2017 (90th)                  SPECIAL AWARD
# 2511     2017           90    2017 (90th)                 VISUAL EFFECTS
# 2512     2017           90    2017 (90th)   WRITING (Adapted Screenplay)
# 2513     2017           90    2017 (90th)  WRITING (Original Screenplay)
# 2514     2017           90    2017 (90th)  WRITING (Original Screenplay)
#
#                                                   name1        name2 name3  \
# 0                                         Emil Jannings          NaN   NaN
# 1                                          Janet Gaynor          NaN   NaN
# 2                               William Cameron Menzies          NaN   NaN
# 3                                        Charles Rosher  Karl Struss   NaN
# 4                                       Lewis Milestone          NaN   NaN
# ...                                                 ...          ...   ...
# 2510                                                NaN          NaN   NaN
# 2511  John Nelson, Gerd Nefzer, Paul Lambert and Ric...          NaN   NaN
# 2512                          Screenplay by James Ivory          NaN   NaN
# 2513                            Written by Jordan Peele          NaN   NaN
# 2514                            Written by Jordan Peele          NaN   NaN
#
#                 film_title                                     character_name  \
# 0         The Last Command  {"General Dolgorucki [Grand Duke Sergius Alexa...
# 1               7th Heaven                                         {"Diane"};
# 2                The Dove;                                                NaN
# 3                  Sunrise                                                NaN
# 4      Two Arabian Knights                                                NaN
# ...                    ...                                                ...
# 2510                   NaN                                                NaN
# 2511     Blade Runner 2049                                                NaN
# 2512  Call Me by Your Name                                                NaN
# 2513               Get Out                                                NaN
# 2514               Get Out                                                NaN
#
#                film_title2       character_name2 film_title3 character_name3  \
# 0     The Way of All Flesh  {"August Schilling"}         NaN             NaN
# 1             Street Angel           {"Angela"};     Sunrise    {"The Wife"}
# 2                  Tempest                   NaN         NaN             NaN
# 3                  Sunrise                   NaN         NaN             NaN
# 4                      NaN                   NaN         NaN             NaN
# ...                    ...                   ...         ...             ...
# 2510                   NaN                   NaN         NaN             NaN
# 2511                   NaN                   NaN         NaN             NaN
# 2512                   NaN                   NaN         NaN             NaN
# 2513                   NaN                   NaN         NaN             NaN
# 2514                   NaN                   NaN         NaN             NaN
#
#      film_title4  character_name4  \
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN
# ...          ...              ...
# 2510         NaN              NaN
# 2511         NaN              NaN
# 2512         NaN              NaN
# 2513         NaN              NaN
# 2514         NaN              NaN
#
#                                      honorary_statement description  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 2510  To Alejandro G. Iñárritu's CARNE y ARENA virtu...         NaN
# 2511                                                NaN         NaN
# 2512                                                NaN         NaN
# 2513                                                NaN         NaN
# 2514                                                NaN         NaN
#
#                                                    note
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     [NOTE: For this awards year, awards were prese...
# 4                                                   NaN
# ...                                                 ...
# 2510                                                NaN
# 2511                                                NaN
# 2512                                                NaN
# 2513                                                NaN
# 2514                                                NaN
#
# [2515 rows x 18 columns]

# %% [markdown]
# The award-year column is no longer needed.

# %%
df = df.drop(['award_year'], axis=1)
df
# Out:
#          year oscars_count                       category  \
# 0     1927/28            1                          ACTOR
# 1     1927/28            1                        ACTRESS
# 2     1927/28            1                  ART DIRECTION
# 3     1927/28            1                 CINEMATOGRAPHY
# 4     1927/28            1     DIRECTING (Comedy Picture)
# ...       ...          ...                            ...
# 2510     2017           90                  SPECIAL AWARD
# 2511     2017           90                 VISUAL EFFECTS
# 2512     2017           90   WRITING (Adapted Screenplay)
# 2513     2017           90  WRITING (Original Screenplay)
# 2514     2017           90  WRITING (Original Screenplay)
#
#                                                   name1        name2 name3  \
# 0                                         Emil Jannings          NaN   NaN
# 1                                          Janet Gaynor          NaN   NaN
# 2                               William Cameron Menzies          NaN   NaN
# 3                                        Charles Rosher  Karl Struss   NaN
# 4                                       Lewis Milestone          NaN   NaN
# ...                                                 ...          ...   ...
# 2510                                                NaN          NaN   NaN
# 2511  John Nelson, Gerd Nefzer, Paul Lambert and Ric...          NaN   NaN
# 2512                          Screenplay by James Ivory          NaN   NaN
# 2513                            Written by Jordan Peele          NaN   NaN
# 2514                            Written by Jordan Peele          NaN   NaN
#
#                 film_title                                     character_name  \
# 0         The Last Command  {"General Dolgorucki [Grand Duke Sergius Alexa...
# 1               7th Heaven                                         {"Diane"};
# 2                The Dove;                                                NaN
# 3                  Sunrise                                                NaN
# 4      Two Arabian Knights                                                NaN
# ...                    ...                                                ...
# 2510                   NaN                                                NaN
# 2511     Blade Runner 2049                                                NaN
# 2512  Call Me by Your Name                                                NaN
# 2513               Get Out                                                NaN
# 2514               Get Out                                                NaN
#
#                film_title2       character_name2 film_title3 character_name3  \
# 0     The Way of All Flesh  {"August Schilling"}         NaN             NaN
# 1             Street Angel           {"Angela"};     Sunrise    {"The Wife"}
# 2                  Tempest                   NaN         NaN             NaN
# 3                  Sunrise                   NaN         NaN             NaN
# 4                      NaN                   NaN         NaN             NaN
# ...                    ...                   ...         ...             ...
# 2510                   NaN                   NaN         NaN             NaN
# 2511                   NaN                   NaN         NaN             NaN
# 2512                   NaN                   NaN         NaN             NaN
# 2513                   NaN                   NaN         NaN             NaN
# 2514                   NaN                   NaN         NaN             NaN
#
#      film_title4  character_name4  \
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN
# ...          ...              ...
# 2510         NaN              NaN
# 2511         NaN              NaN
# 2512         NaN              NaN
# 2513         NaN              NaN
# 2514         NaN              NaN
#
#                                      honorary_statement description  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 2510  To Alejandro G. Iñárritu's CARNE y ARENA virtu...         NaN
# 2511                                                NaN         NaN
# 2512                                                NaN         NaN
# 2513                                                NaN         NaN
# 2514                                                NaN         NaN
#
#                                                    note
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     [NOTE: For this awards year, awards were prese...
# 4                                                   NaN
# ...                                                 ...
# 2510                                                NaN
# 2511                                                NaN
# 2512                                                NaN
# 2513                                                NaN
# 2514                                                NaN
#
# [2515 rows x 17 columns]

# %% [markdown]
# #### 1.3 Check for duplicates and delete them
#
# In a first step it will be tested if there are any duplicates.

# %%
duplicates =df[df.duplicated(keep=False)]             #to check if there are duplicates
duplicates
# Out:
#          year oscars_count                       category  \
# 9     1927/28            1    UNIQUE AND ARTISTIC PICTURE
# 10    1927/28            1    UNIQUE AND ARTISTIC PICTURE
# 21    1929/30            3                          ACTOR
# 22    1929/30            3                          ACTOR
# 75       1934            7             ASSISTANT DIRECTOR
# ...       ...          ...                            ...
# 2359     2012           85       SHORT FILM (Live Action)
# 2402     2014           87                   BEST PICTURE
# 2403     2014           87                   BEST PICTURE
# 2513     2017           90  WRITING (Original Screenplay)
# 2514     2017           90  WRITING (Original Screenplay)
#
#                                                   name1 name2 name3  \
# 9                                                   Fox   NaN   NaN
# 10                                                  Fox   NaN   NaN
# 21                                        George Arliss   NaN   NaN
# 22                                        George Arliss   NaN   NaN
# 75                                          John Waters   NaN   NaN
# ...                                                 ...   ...   ...
# 2359                                  Shawn Christensen   NaN   NaN
# 2402  Alejandro G. Iñárritu, John Lesher and James W...   NaN   NaN
# 2403  Alejandro G. Iñárritu, John Lesher and James W...   NaN   NaN
# 2513                            Written by Jordan Peele   NaN   NaN
# 2514                            Written by Jordan Peele   NaN   NaN
#
#                                            film_title         character_name  \
# 9                                             Sunrise                    NaN
# 10                                            Sunrise                    NaN
# 21                                           Disraeli  {"Benjamin Disraeli"}
# 22                                           Disraeli  {"Benjamin Disraeli"}
# 75                                        Viva Villa!                    NaN
# ...                                               ...                    ...
# 2359                                           Curfew                    NaN
# 2402  Birdman or (The Unexpected Virtue of Ignorance)                    NaN
# 2403  Birdman or (The Unexpected Virtue of Ignorance)                    NaN
# 2513                                          Get Out                    NaN
# 2514                                          Get Out                    NaN
#
#      film_title2 character_name2 film_title3 character_name3 film_title4  \
# 9            NaN             NaN         NaN             NaN         NaN
# 10           NaN             NaN         NaN             NaN         NaN
# 21           NaN             NaN         NaN             NaN         NaN
# 22           NaN             NaN         NaN             NaN         NaN
# 75           NaN             NaN         NaN             NaN         NaN
# ...          ...             ...         ...             ...         ...
# 2359         NaN             NaN         NaN             NaN         NaN
# 2402         NaN             NaN         NaN             NaN         NaN
# 2403         NaN             NaN         NaN             NaN         NaN
# 2513         NaN             NaN         NaN             NaN         NaN
# 2514         NaN             NaN         NaN             NaN         NaN
#
#       character_name4 honorary_statement description  \
# 9                 NaN                NaN         NaN
# 10                NaN                NaN         NaN
# 21                NaN                NaN         NaN
# 22                NaN                NaN         NaN
# 75                NaN                NaN         NaN
# ...               ...                ...         ...
# 2359              NaN                NaN         NaN
# 2402              NaN                NaN         NaN
# 2403              NaN                NaN         NaN
# 2513              NaN                NaN         NaN
# 2514              NaN                NaN         NaN
#
#                                                    note
# 9                                                   NaN
# 10                                                  NaN
# 21    [NOTE: As allowed by the award rules for this ...
# 22    [NOTE: As allowed by the award rules for this ...
# 75                                                  NaN
# ...                                                 ...
# 2359                                                NaN
# 2402                                                NaN
# 2403                                                NaN
# 2513                                                NaN
# 2514                                                NaN
#
# [120 rows x 17 columns]

# %% [markdown]
# Delete all the duplicates and reset the index numbers.

# %%
df = df.drop_duplicates()
df = df.reset_index(drop=True)
len(df.index) # check how many rows there are left
# Out:
# 2454

# %% [markdown]
# #### 1.4 Delete semicolon in the end of some words
#
# Removal of the semicolon in the end of names in the colums character_name/2 and film_title/2

# %%
# Check for missing values in the column
#film_name
mask_missing = df['film_title'].isna()

# Check if values end with a semicolon and are not missing
mask_semicolon = df['film_title'].str.endswith(';') & ~mask_missing

# Remove semicolons in values that end with a semicolon
df.loc[mask_semicolon, 'film_title'] = df.loc[mask_semicolon, 'film_title'].str.rstrip(';')

# redo the steps for film_name2
mask_missing = df['film_title2'].isna()
mask_semicolon = df['film_title2'].str.endswith(';') & ~mask_missing
df.loc[mask_semicolon, 'film_title2'] = df.loc[mask_semicolon, 'film_title2'].str.rstrip(';')

# redo the steps for Character_name
mask_missing = df['character_name'].isna()
mask_semicolon = df['character_name'].str.endswith(';') & ~mask_missing
df.loc[mask_semicolon, 'character_name'] = df.loc[mask_semicolon, 'character_name'].str.rstrip(';')

# redo the steps for Character_name2
mask_missing = df['character_name2'].isna()
mask_semicolon = df['character_name2'].str.endswith(';') & ~mask_missing
df.loc[mask_semicolon, 'character_name2'] = df.loc[mask_semicolon, 'character_name2'].str.rstrip(';')

df
# Out:
#          year oscars_count                       category  \
# 0     1927/28            1                          ACTOR
# 1     1927/28            1                        ACTRESS
# 2     1927/28            1                  ART DIRECTION
# 3     1927/28            1                 CINEMATOGRAPHY
# 4     1927/28            1     DIRECTING (Comedy Picture)
# ...       ...          ...                            ...
# 2449     2017           90                   SOUND MIXING
# 2450     2017           90                  SPECIAL AWARD
# 2451     2017           90                 VISUAL EFFECTS
# 2452     2017           90   WRITING (Adapted Screenplay)
# 2453     2017           90  WRITING (Original Screenplay)
#
#                                                   name1        name2 name3  \
# 0                                         Emil Jannings          NaN   NaN
# 1                                          Janet Gaynor          NaN   NaN
# 2                               William Cameron Menzies          NaN   NaN
# 3                                        Charles Rosher  Karl Struss   NaN
# 4                                       Lewis Milestone          NaN   NaN
# ...                                                 ...          ...   ...
# 2449  Gregg Landaker, Gary A. Rizzo and Mark Weingarten          NaN   NaN
# 2450                                                NaN          NaN   NaN
# 2451  John Nelson, Gerd Nefzer, Paul Lambert and Ric...          NaN   NaN
# 2452                          Screenplay by James Ivory          NaN   NaN
# 2453                            Written by Jordan Peele          NaN   NaN
#
#                 film_title                                     character_name  \
# 0         The Last Command  {"General Dolgorucki [Grand Duke Sergius Alexa...
# 1               7th Heaven                                          {"Diane"}
# 2                 The Dove                                                NaN
# 3                  Sunrise                                                NaN
# 4      Two Arabian Knights                                                NaN
# ...                    ...                                                ...
# 2449               Dunkirk                                                NaN
# 2450                   NaN                                                NaN
# 2451     Blade Runner 2049                                                NaN
# 2452  Call Me by Your Name                                                NaN
# 2453               Get Out                                                NaN
#
#                film_title2       character_name2 film_title3 character_name3  \
# 0     The Way of All Flesh  {"August Schilling"}         NaN             NaN
# 1             Street Angel            {"Angela"}     Sunrise    {"The Wife"}
# 2                  Tempest                   NaN         NaN             NaN
# 3                  Sunrise                   NaN         NaN             NaN
# 4                      NaN                   NaN         NaN             NaN
# ...                    ...                   ...         ...             ...
# 2449                   NaN                   NaN         NaN             NaN
# 2450                   NaN                   NaN         NaN             NaN
# 2451                   NaN                   NaN         NaN             NaN
# 2452                   NaN                   NaN         NaN             NaN
# 2453                   NaN                   NaN         NaN             NaN
#
#      film_title4  character_name4  \
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN
# ...          ...              ...
# 2449         NaN              NaN
# 2450         NaN              NaN
# 2451         NaN              NaN
# 2452         NaN              NaN
# 2453         NaN              NaN
#
#                                      honorary_statement description  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 2449                                                NaN         NaN
# 2450  To Alejandro G. Iñárritu's CARNE y ARENA virtu...         NaN
# 2451                                                NaN         NaN
# 2452                                                NaN         NaN
# 2453                                                NaN         NaN
#
#                                                    note
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     [NOTE: For this awards year, awards were prese...
# 4                                                   NaN
# ...                                                 ...
# 2449                                                NaN
# 2450                                                NaN
# 2451                                                NaN
# 2452                                                NaN
# 2453                                                NaN
#
# [2454 rows x 17 columns]

# %% [markdown]
# #### 1.5 Clean all the character_names
#
# All the character Names are written in the following format: {"Character"}. To have clean data the {""} will be removed so that only the name will be left. This can be done in one step for the whole dataframe:

# %%
df = df.applymap(lambda x: x.strip('{}') if isinstance(x, str) else x)
df = df.applymap(lambda x: x.strip('""') if isinstance(x, str) else x)

# %%
df
# Out:
#          year oscars_count                       category  \
# 0     1927/28            1                          ACTOR
# 1     1927/28            1                        ACTRESS
# 2     1927/28            1                  ART DIRECTION
# 3     1927/28            1                 CINEMATOGRAPHY
# 4     1927/28            1     DIRECTING (Comedy Picture)
# ...       ...          ...                            ...
# 2449     2017           90                   SOUND MIXING
# 2450     2017           90                  SPECIAL AWARD
# 2451     2017           90                 VISUAL EFFECTS
# 2452     2017           90   WRITING (Adapted Screenplay)
# 2453     2017           90  WRITING (Original Screenplay)
#
#                                                   name1        name2 name3  \
# 0                                         Emil Jannings          NaN   NaN
# 1                                          Janet Gaynor          NaN   NaN
# 2                               William Cameron Menzies          NaN   NaN
# 3                                        Charles Rosher  Karl Struss   NaN
# 4                                       Lewis Milestone          NaN   NaN
# ...                                                 ...          ...   ...
# 2449  Gregg Landaker, Gary A. Rizzo and Mark Weingarten          NaN   NaN
# 2450                                                NaN          NaN   NaN
# 2451  John Nelson, Gerd Nefzer, Paul Lambert and Ric...          NaN   NaN
# 2452                          Screenplay by James Ivory          NaN   NaN
# 2453                            Written by Jordan Peele          NaN   NaN
#
#                 film_title                                     character_name  \
# 0         The Last Command  General Dolgorucki [Grand Duke Sergius Alexander]
# 1               7th Heaven                                              Diane
# 2                 The Dove                                                NaN
# 3                  Sunrise                                                NaN
# 4      Two Arabian Knights                                                NaN
# ...                    ...                                                ...
# 2449               Dunkirk                                                NaN
# 2450                   NaN                                                NaN
# 2451     Blade Runner 2049                                                NaN
# 2452  Call Me by Your Name                                                NaN
# 2453               Get Out                                                NaN
#
#                film_title2   character_name2 film_title3 character_name3  \
# 0     The Way of All Flesh  August Schilling         NaN             NaN
# 1             Street Angel            Angela     Sunrise        The Wife
# 2                  Tempest               NaN         NaN             NaN
# 3                  Sunrise               NaN         NaN             NaN
# 4                      NaN               NaN         NaN             NaN
# ...                    ...               ...         ...             ...
# 2449                   NaN               NaN         NaN             NaN
# 2450                   NaN               NaN         NaN             NaN
# 2451                   NaN               NaN         NaN             NaN
# 2452                   NaN               NaN         NaN             NaN
# 2453                   NaN               NaN         NaN             NaN
#
#      film_title4  character_name4  \
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN
# ...          ...              ...
# 2449         NaN              NaN
# 2450         NaN              NaN
# 2451         NaN              NaN
# 2452         NaN              NaN
# 2453         NaN              NaN
#
#                                      honorary_statement description  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 2449                                                NaN         NaN
# 2450  To Alejandro G. Iñárritu's CARNE y ARENA virtu...         NaN
# 2451                                                NaN         NaN
# 2452                                                NaN         NaN
# 2453                                                NaN         NaN
#
#                                                    note
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     [NOTE: For this awards year, awards were prese...
# 4                                                   NaN
# ...                                                 ...
# 2449                                                NaN
# 2450                                                NaN
# 2451                                                NaN
# 2452                                                NaN
# 2453                                                NaN
#
# [2454 rows x 17 columns]

# %% [markdown]
# #### 1.6 Remove not needed Note: in note column
#
# Remove NOTE: and [] from the note column.

# %%
# Remove the [Note: prefix from values in the column
df['note'] = df['note'].str.replace('\[NOTE: ', '')
# remove the ] in the end
mask_missing = df['note'].isna()
mask_semicolon = df['note'].str.endswith(']') & ~mask_missing
df.loc[mask_semicolon, 'note'] = df.loc[mask_semicolon, 'note'].str.rstrip(']')

df
# Out:
# /tmp/ipykernel_191956/1806846337.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['note'] = df['note'].str.replace('\[NOTE: ', '')
#          year oscars_count                       category  \
# 0     1927/28            1                          ACTOR
# 1     1927/28            1                        ACTRESS
# 2     1927/28            1                  ART DIRECTION
# 3     1927/28            1                 CINEMATOGRAPHY
# 4     1927/28            1     DIRECTING (Comedy Picture)
# ...       ...          ...                            ...
# 2449     2017           90                   SOUND MIXING
# 2450     2017           90                  SPECIAL AWARD
# 2451     2017           90                 VISUAL EFFECTS
# 2452     2017           90   WRITING (Adapted Screenplay)
# 2453     2017           90  WRITING (Original Screenplay)
#
#                                                   name1        name2 name3  \
# 0                                         Emil Jannings          NaN   NaN
# 1                                          Janet Gaynor          NaN   NaN
# 2                               William Cameron Menzies          NaN   NaN
# 3                                        Charles Rosher  Karl Struss   NaN
# 4                                       Lewis Milestone          NaN   NaN
# ...                                                 ...          ...   ...
# 2449  Gregg Landaker, Gary A. Rizzo and Mark Weingarten          NaN   NaN
# 2450                                                NaN          NaN   NaN
# 2451  John Nelson, Gerd Nefzer, Paul Lambert and Ric...          NaN   NaN
# 2452                          Screenplay by James Ivory          NaN   NaN
# 2453                            Written by Jordan Peele          NaN   NaN
#
#                 film_title                                     character_name  \
# 0         The Last Command  General Dolgorucki [Grand Duke Sergius Alexander]
# 1               7th Heaven                                              Diane
# 2                 The Dove                                                NaN
# 3                  Sunrise                                                NaN
# 4      Two Arabian Knights                                                NaN
# ...                    ...                                                ...
# 2449               Dunkirk                                                NaN
# 2450                   NaN                                                NaN
# 2451     Blade Runner 2049                                                NaN
# 2452  Call Me by Your Name                                                NaN
# 2453               Get Out                                                NaN
#
#                film_title2   character_name2 film_title3 character_name3  \
# 0     The Way of All Flesh  August Schilling         NaN             NaN
# 1             Street Angel            Angela     Sunrise        The Wife
# 2                  Tempest               NaN         NaN             NaN
# 3                  Sunrise               NaN         NaN             NaN
# 4                      NaN               NaN         NaN             NaN
# ...                    ...               ...         ...             ...
# 2449                   NaN               NaN         NaN             NaN
# 2450                   NaN               NaN         NaN             NaN
# 2451                   NaN               NaN         NaN             NaN
# 2452                   NaN               NaN         NaN             NaN
# 2453                   NaN               NaN         NaN             NaN
#
#      film_title4  character_name4  \
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN
# 3            NaN              NaN
# 4            NaN              NaN
# ...          ...              ...
# 2449         NaN              NaN
# 2450         NaN              NaN
# 2451         NaN              NaN
# 2452         NaN              NaN
# 2453         NaN              NaN
#
#                                      honorary_statement description  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 2449                                                NaN         NaN
# 2450  To Alejandro G. Iñárritu's CARNE y ARENA virtu...         NaN
# 2451                                                NaN         NaN
# 2452                                                NaN         NaN
# 2453                                                NaN         NaN
#
#                                                    note
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     For this awards year, awards were presented in...
# 4                                                   NaN
# ...                                                 ...
# 2449                                                NaN
# 2450                                                NaN
# 2451                                                NaN
# 2452                                                NaN
# 2453                                                NaN
#
# [2454 rows x 17 columns]

# %%
df.loc[12,'note'] # check if the [NOTE: ] is gone.
# Out:
# 'This award was not associated with any specific film title.'

# %% [markdown]
# #### 1.7 Check if there are special characters to be cleaned in film title column
#
# Look for special characters and clean them if necessary

# %%
# all the special characters can be added
pattern = r'[@éàè§^~]'

# create special with all the values that contain a special character
special = df['film_title'].str.contains(pattern, na=False)

# filter the dataframe for the special values
values_with_special_characters = df[special]

# show the rows including a special character in the defined column
values_with_special_characters
# Out:
#       year oscars_count                      category  \
# 2279  2012           85  ACTRESS IN A SUPPORTING ROLE
# 2292  2012           85        MAKEUP AND HAIRSTYLING
# 2302  2012           85                  SOUND MIXING
#
#                                            name1 name2 name3      film_title  \
# 2279                               Anne Hathaway   NaN   NaN  Les Misérables
# 2292            Lisa Westcott and Julie Dartnell   NaN   NaN  Les Misérables
# 2302  Andy Nelson, Mark Paterson and Simon Hayes   NaN   NaN  Les Misérables
#
#      character_name film_title2 character_name2 film_title3 character_name3  \
# 2279        Fantine         NaN             NaN         NaN             NaN
# 2292            NaN         NaN             NaN         NaN             NaN
# 2302            NaN         NaN             NaN         NaN             NaN
#
#      film_title4  character_name4 honorary_statement description note
# 2279         NaN              NaN                NaN         NaN  NaN
# 2292         NaN              NaN                NaN         NaN  NaN
# 2302         NaN              NaN                NaN         NaN  NaN

# %% [markdown]
# ### 2. Enrichment of the data

# %% [markdown]
# #### 2.1 Add column True/False
#
# As a first step we would like to know if there are more awards won by an actor/actress or a director/directing position. A new column is created with the Values True/False related to the fact who the winner of the award was.

# %%
# parts of word to be included
words = 'ACTOR|ACTRESS|DIRECT'  

# Create a new column "act_dir" that checks for the specified part of the word
df['act_dir'] = df['category'].str.contains(words, case=False)

df.act_dir.sum()
# Out:
# 590

# %% [markdown]
# #### 2.2 Award won by single or multiple person
#
# Another column is created if an award was won by only one person or by multiple ones. This is shown in the new column winner_type.

# %%
# Create a new column "winner_type" to indicate if it's a single winner or multiple winners
df['winner_type'] = 'Single Winner'

# Check if there are additional names in name2 and name3 columns
df.loc[df['name2'].notna() | df['name3'].notna(), 'winner_type'] = 'Multiple Winners'

df.winner_type.value_counts()
# Out:
# Single Winner       2443
# Multiple Winners      11
# Name: winner_type, dtype: int64

# %%
df[df.columns[-2:]]
# Out:
#       act_dir       winner_type
# 0        True     Single Winner
# 1        True     Single Winner
# 2        True     Single Winner
# 3       False  Multiple Winners
# 4        True     Single Winner
# ...       ...               ...
# 2449    False     Single Winner
# 2450    False     Single Winner
# 2451    False     Single Winner
# 2452    False     Single Winner
# 2453    False     Single Winner
#
# [2454 rows x 2 columns]

# %% [markdown]
# #### Separate two winners to two rows

# %%
new_df = pd.DataFrame(columns=['year', 'oscars_count', 'category', 'name', 'film_title', 'character_name', 'honorary_statement',
                               'description', 'note', 'act_dir', 'winner_type'])

# Iterate over each row in the original dataframe
for index, row in df.iterrows():
    # Extract the common values from the first row
    year = row['year']
    oscars_count = row['oscars_count']
    category = row['category']
    honorary_statement = row['honorary_statement']
    description = row['description']
    note = row['note']
    act_dir = row['act_dir']
    winner_type = row['winner_type']
    
    # Extract the values from the first set of columns (name1, film_title, character_name)
    name1 = row['name1']
    film_title = row['film_title']
    character_name = row['character_name']
    
    # Create a new row in the new dataframe with the extracted values
    new_row = pd.DataFrame({'year': [year], 'oscars_count': [oscars_count], 'category': [category],
                            'name': [name1], 'film_title': [film_title], 'character_name': [character_name],
                            'honorary_statement' : [honorary_statement],'description' : [description], 
                            'note' : [note], 'act_dir' : [act_dir], 'winner_type' : [winner_type]})
    new_df = pd.concat([new_df, new_row], ignore_index=True)
    
    # Check if the second set of columns has values and copy them to a new row if conditions are met
    if pd.notna(row['name2']) and pd.notna(row['film_title2']):
        film_title2 = row['film_title2']
        character_name2 = row['character_name2']
        name2 = row['name2']
        
        new_row = pd.DataFrame({'year': [year], 'oscars_count': [oscars_count], 'category': [category],
                                'name': [name2], 'film_title': [film_title2], 'character_name': [character_name2],
                                'honorary_statement' : [honorary_statement],'description' : [description], 
                                'note' : [note], 'act_dir' : [act_dir], 'winner_type' : [winner_type]})
        new_df = pd.concat([new_df, new_row], ignore_index=True)
    
    # Check if the third set of columns has values and copy them to a new row if conditions are met
    if pd.notna(row['name3']) and pd.notna(row['film_title3']):
        film_title3 = row['film_title3']
        character_name3 = row['character_name3']
        name3 = row['name3']
        
        new_row = pd.DataFrame({'year': [year], 'oscars_count': [oscars_count], 'category': [category],
                                'name': [name3], 'film_title': [film_title3], 'character_name': [character_name3],
                                'honorary_statement' : [honorary_statement],'description' : [description], 
                                'note' : [note], 'act_dir' : [act_dir], 'winner_type' : [winner_type]})
        new_df = pd.concat([new_df, new_row], ignore_index=True)
    
    # Check if the fourth set of columns has values and copy them to a new row if conditions are met
    if pd.notna(row['film_title4']):
        film_title4 = row['film_title4']
        character_name4 = row['character_name4']
        
        new_row = pd.DataFrame({'year': [year], 'oscars_count': [oscars_count], 'category': [category],
                                'name': [name1], 'film_title': [film_title4], 'character_name': [character_name4],
                                'honorary_statement' : [honorary_statement],'description' : [description], 
                                'note' : [note], 'act_dir' : [act_dir], 'winner_type' : [winner_type]})
        new_df = pd.concat([new_df, new_row]).reset_index(drop=True)
# Out:
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:38: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:38: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# ...
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)
# /tmp/ipykernel_191956/3983208180.py:26: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   new_df = pd.concat([new_df, new_row], ignore_index=True)

# %%
df = new_df

# %%
df
# Out:
#          year oscars_count                       category  \
# 0     1927/28            1                          ACTOR
# 1     1927/28            1                        ACTRESS
# 2     1927/28            1                  ART DIRECTION
# 3     1927/28            1                 CINEMATOGRAPHY
# 4     1927/28            1                 CINEMATOGRAPHY
# ...       ...          ...                            ...
# 2460     2017           90                   SOUND MIXING
# 2461     2017           90                  SPECIAL AWARD
# 2462     2017           90                 VISUAL EFFECTS
# 2463     2017           90   WRITING (Adapted Screenplay)
# 2464     2017           90  WRITING (Original Screenplay)
#
#                                                    name            film_title  \
# 0                                         Emil Jannings      The Last Command
# 1                                          Janet Gaynor            7th Heaven
# 2                               William Cameron Menzies              The Dove
# 3                                        Charles Rosher               Sunrise
# 4                                           Karl Struss               Sunrise
# ...                                                 ...                   ...
# 2460  Gregg Landaker, Gary A. Rizzo and Mark Weingarten               Dunkirk
# 2461                                                NaN                   NaN
# 2462  John Nelson, Gerd Nefzer, Paul Lambert and Ric...     Blade Runner 2049
# 2463                          Screenplay by James Ivory  Call Me by Your Name
# 2464                            Written by Jordan Peele               Get Out
#
#                                          character_name  \
# 0     General Dolgorucki [Grand Duke Sergius Alexander]
# 1                                                 Diane
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2460                                                NaN
# 2461                                                NaN
# 2462                                                NaN
# 2463                                                NaN
# 2464                                                NaN
#
#                                      honorary_statement description  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 2460                                                NaN         NaN
# 2461  To Alejandro G. Iñárritu's CARNE y ARENA virtu...         NaN
# 2462                                                NaN         NaN
# 2463                                                NaN         NaN
# 2464                                                NaN         NaN
#
#                                                    note act_dir  \
# 0                                                   NaN    True
# 1                                                   NaN    True
# 2                                                   NaN    True
# 3     For this awards year, awards were presented in...   False
# 4     For this awards year, awards were presented in...   False
# ...                                                 ...     ...
# 2460                                                NaN   False
# 2461                                                NaN   False
# 2462                                                NaN   False
# 2463                                                NaN   False
# 2464                                                NaN   False
#
#            winner_type
# 0        Single Winner
# 1        Single Winner
# 2        Single Winner
# 3     Multiple Winners
# 4     Multiple Winners
# ...                ...
# 2460     Single Winner
# 2461     Single Winner
# 2462     Single Winner
# 2463     Single Winner
# 2464     Single Winner
#
# [2465 rows x 11 columns]

# %% [markdown]
# #### 2.3 Number of awards per movie
#
# Create a new list with the movie titles and the number of awards.

# %%
# Create an empty dictionary 
film_data = {}

# Iterate over the columns containing the film titles
for column in ['film_title']:
    # Get the film titles from the column and count their occurrences
    film_counts = df[column].value_counts()
    # Update the film_data dictionary with the film titles and their Oscar counts
    film_data.update(film_counts)

# Create a new dataframe from the film_data dictionary
sep_df = pd.DataFrame.from_dict(film_data, orient='index', columns=['oscar_total'])

# Reset the index and rename the columns
sep_df = sep_df.reset_index().rename(columns={'index': 'film_title'})

sep_df
# Out:
#                                          film_title  oscar_total
# 0                                           Titanic           12
# 1                                           Ben-Hur           11
# 2     The Lord of the Rings: The Return of the King           11
# 3                                   West Side Story           10
# 4                                              Gigi            9
# ...                                             ...          ...
# 1239                                      Black Fox            1
# 1240                                   Dylan Thomas            1
# 1241                             Sundays and Cybele            1
# 1242               Meredith Willson's The Music Man            1
# 1243                                        Get Out            1
#
# [1244 rows x 2 columns]

# %% [markdown]
# This would be a possiblility to rename the columns so it fits together with the other datasets. However, this can also be done in a later step. When the data is merged or even when it is uploaded to a database.

# %%
#df = df.rename(columns={'year': 'Year', 'oscars_count': 'OscarsCount', 'category': 'Category', 'name1': 'Name1', 
#                        'name2': 'Name2', 'name3': 'Name3','film_title': 'FilmTitle', 'film_title2': 'FilmTitle2',
#                       'film_title3': 'FilmTitle3', 'film_title4': 'FilmTitle4', 'character_name': 'CharacterName',
#                       'character_name2': 'CharacterName2', 'character_name3': 'CharacterName3', 
#                        'character_name4': 'CharacterName4',  'honorary_statement': 'HonoraryStatement', 
#                        'description': 'Description', 'note': 'Note'})

#df

# %%
df = df.rename(columns={'oscars_count': 'oscars_held'})

# %% [markdown]
# ### 3. Setting an index row
#
# Before saving the file to a csv it was necessary to create a new column containing the index number. This makes it possible to add the whole dataset to the MariaDB. To upload and link a dataset a primary key is needed. As seen above there are some movie titles listed more than once in the dataframe. With the index number and the film title a unique primary key can be created.

# %%
df_with_index = df.reset_index()
df_with_index
# Out:
#       index     year oscars_held                       category  \
# 0         0  1927/28           1                          ACTOR
# 1         1  1927/28           1                        ACTRESS
# 2         2  1927/28           1                  ART DIRECTION
# 3         3  1927/28           1                 CINEMATOGRAPHY
# 4         4  1927/28           1                 CINEMATOGRAPHY
# ...     ...      ...         ...                            ...
# 2460   2460     2017          90                   SOUND MIXING
# 2461   2461     2017          90                  SPECIAL AWARD
# 2462   2462     2017          90                 VISUAL EFFECTS
# 2463   2463     2017          90   WRITING (Adapted Screenplay)
# 2464   2464     2017          90  WRITING (Original Screenplay)
#
#                                                    name            film_title  \
# 0                                         Emil Jannings      The Last Command
# 1                                          Janet Gaynor            7th Heaven
# 2                               William Cameron Menzies              The Dove
# 3                                        Charles Rosher               Sunrise
# 4                                           Karl Struss               Sunrise
# ...                                                 ...                   ...
# 2460  Gregg Landaker, Gary A. Rizzo and Mark Weingarten               Dunkirk
# 2461                                                NaN                   NaN
# 2462  John Nelson, Gerd Nefzer, Paul Lambert and Ric...     Blade Runner 2049
# 2463                          Screenplay by James Ivory  Call Me by Your Name
# 2464                            Written by Jordan Peele               Get Out
#
#                                          character_name  \
# 0     General Dolgorucki [Grand Duke Sergius Alexander]
# 1                                                 Diane
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2460                                                NaN
# 2461                                                NaN
# 2462                                                NaN
# 2463                                                NaN
# 2464                                                NaN
#
#                                      honorary_statement description  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 2460                                                NaN         NaN
# 2461  To Alejandro G. Iñárritu's CARNE y ARENA virtu...         NaN
# 2462                                                NaN         NaN
# 2463                                                NaN         NaN
# 2464                                                NaN         NaN
#
#                                                    note act_dir  \
# 0                                                   NaN    True
# 1                                                   NaN    True
# 2                                                   NaN    True
# 3     For this awards year, awards were presented in...   False
# 4     For this awards year, awards were presented in...   False
# ...                                                 ...     ...
# 2460                                                NaN   False
# 2461                                                NaN   False
# 2462                                                NaN   False
# 2463                                                NaN   False
# 2464                                                NaN   False
#
#            winner_type
# 0        Single Winner
# 1        Single Winner
# 2        Single Winner
# 3     Multiple Winners
# 4     Multiple Winners
# ...                ...
# 2460     Single Winner
# 2461     Single Winner
# 2462     Single Winner
# 2463     Single Winner
# 2464     Single Winner
#
# [2465 rows x 12 columns]

# %% [markdown]
# ### 4. Create a csv files
#
# A new csv file with the cleaned data is created and saved as B_stage3. The newly created dataframe with the awards by movies is also exported to a csv file.

# %%
B_stage3 = df_with_index.to_csv("../Data/B_stage3.csv", index = False)

# %%
B_sum_df = sep_df.to_csv("../Data/B_sum_df.csv", index = False)
